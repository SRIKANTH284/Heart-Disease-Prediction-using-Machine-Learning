# %% [markdown]
# # NAME :BADAVATH SRIKANTH
# # ROLL NUMBER:67
# # REGISTRATION NUMBER:12019441

# %%
# !pip install pyfiglet typer

import pyfiglet
import typer
import time

ascii_art = pyfiglet.figlet_format("heart disease prediction by Srikanth")
for letter in ascii_art:
    typer.echo(letter, nl=False)
    time.sleep(0.05)
# Out:
# ...
#  _                     _         _ _
# | |__   ___  __ _ _ __| |_    __| (_)___  ___  __ _ ___  ___
# | '_ \ / _ \/ _` | '__| __|  / _` | / __|/ _ \/ _` / __|/ _ \
# | | | |  __/ (_| | |  | |_  | (_| | \__ \  __/ (_| \__ \  __/
# |_| |_|\___|\__,_|_|   \__|  \__,_|_|___/\___|\__,_|___/\___|
#
#                     _ _      _   _               _
#  _ __  _ __ ___  __| (_) ___| |_(_) ___  _ __   | |__  _   _
# | '_ \| '__/ _ \/ _` | |/ __| __| |/ _ \| '_ \  | '_ \| | | |
# | |_) | | |  __/ (_| | | (__| |_| | (_) | | | | | |_) | |_| |
# | .__/|_|  \___|\__,_|_|\___|\__|_|\___/|_| |_| |_.__/ \__, |
# |_|                                                    |___/
#  ____       _ _               _   _
# / ___| _ __(_) | ____ _ _ __ | |_| |__
# \___ \| '__| | |/ / _` | '_ \| __| '_ \
#  ___) | |  | |   < (_| | | | | |_| | | |
# |____/|_|  |_|_|\_\__,_|_| |_|\__|_| |_|

# %% [markdown]
# # Heart Disease Prediction

# %% [markdown]
# This dataset consists of 11 features and a target variable. It has 6 nominal variables and 5 numeric variables. The detailed description of all the features are as follows:
#
# 1. Age: Patients Age in years (Numeric)
# 2. Sex: Gender of patient (Male - 1, Female - 0) (Nominal)
# 3. Chest Pain Type: Type of chest pain experienced by patient categorized into 1 typical, 2 typical angina, 3 non-anginal pain,    asymptomatic (Nominal)
# 4. resting bp s: Level of blood pressure at resting mode in mm/HG (Numerical)
# 5. cholestrol: Serum cholestrol in mg/dl (Numeric)
# 6. fasting blood sugar: Blood sugar levels on fasting > 120 mg/dl represents as 1 in case of true and 0 as false (Nominal)
# 7. resting ecg: Result of electrocardiogram while at rest are represented in 3 distinct values 0 : Normal 1: Abnormality in ST-     T   wave 2: Left ventricular hypertrophy (Nominal)
# 8. max heart rate: Maximum heart rate achieved (Numeric)
# 9. exercise angina: Angina induced by exercise 0 depicting NO 1 depicting Yes (Nominal)
# 10. oldpeak: Exercise induced ST-depression in comparison with the state of rest (Numeric)
# 11. ST slope: ST segment measured in terms of slope during peak exercise 0: Normal 1: Upsloping 2: Flat 3: Downsloping (Nominal)
#     Target variable
# 12. target: It is the target variable which we have to predict 1 means patient is suffering from heart risk and 0 means patient is normal.

# %% [markdown]
# #####  1 means patient is suffering from heart risk and
#
# #### 0 means patient is normal.

# %% [markdown]
# ## I. Importing essential libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import os
print(os.listdir())

import warnings
warnings.filterwarnings('ignore')
# Out:
# ['.ipynb_checkpoints', 'example_test.csv', 'example_train.csv', 'heart.csv', 'Kern_County.csv', 'Naive_Bayes_Multinomial_Bernoulli_+Demo.ipynb', 'Price_Predictor.pkl', 'Scaler.pkl', 'train (1).csv', 'Untitled.ipynb', 'Untitled1.ipynb', 'Used Phone Price Prediction Project.ipynb', 'used_device_data.csv']

# %% [markdown]
# - The above code imports several Python libraries, including numpy, pandas, matplotlib, and seaborn.
# - It also sets up the Jupyter Notebook to display matplotlib graphs inline.
# - The code then imports the os module and prints the contents of the current directory using the os.listdir() function.
# - The directory contains several files, including example_test.csv, example_train.csv, heart.csv, Kern_County.csv, Naive_Bayes_Multinomial_Bernoulli_+Demo.ipynb, Price_Predictor.pkl, Scaler.pkl, train (1).csv, Untitled.ipynb, Untitled1.ipynb, and used_device_data.csv.
# - The purpose of the code is not clear without additional context, but it seems to be setting up the environment for some kind of data analysis or machine learning project.
# - The code suppresses warnings using the warnings module, which suggests that the code may have been developed by someone who wants to hide certain warnings.

# %% [markdown]
# ## II. Importing and understanding our dataset

# %%
data = pd.read_csv("heart.csv")
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# - The dataset is related to heart disease and contains information on various factors that may contribute to the development of the disease. The columns of the dataset are:
#
# Age: Age of the patient
# Sex: Gender of the patient
# ChestPainType: Type of chest pain experienced by the patient
# RestingBP: Resting blood pressure of the patient
# Cholesterol: Serum cholesterol level of the patient
# FastingBS: Fasting blood sugar level of the patient
# RestingECG: Electrocardiogram readings taken while the patient is at rest
# MaxHR: Maximum heart rate achieved during exercise
# ExerciseAngina: Whether the patient experienced angina during exercise
# Oldpeak: ST depression induced by exercise relative to rest
# ST_Slope: The slope of the peak exercise ST segment
# HeartDisease: The presence of heart disease in the patient (1 = yes, 0 = no)
# - It would be interesting to perform some exploratory data analysis to gain a better understanding of the dataset. This could include calculating summary statistics for each column, visualizing the distribution of each variable, and exploring the relationships between the different variables using correlation matrices or scatter plots.
#
# - Additionally, it could be useful to perform some modeling to see if any of the variables are predictive of heart disease. This could involve splitting the data into training and testing sets, selecting a suitable machine learning algorithm, and training the model on the training data before evaluating its performance on the testing data.
#
# - Overall, this dataset has the potential to provide valuable insights into the factors that contribute to heart disease, and further analysis could help identify effective interventions to prevent or treat this condition.

# %% [markdown]
# #### Verifying it as a 'dataframe' object in pandas

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# - The output "pandas.core.frame.DataFrame" indicates that "data" is a Pandas DataFrame, a two-dimensional tabular data structure used in the Pandas library for data manipulation and analysis.
# - The DataFrame contains information related to heart disease with 12 columns representing variables such as age, sex, blood pressure, cholesterol level, and heart disease presence. DataFrames provide a flexible way to manipulate and analyze data, making it possible to gain valuable insights and make data-driven decisions in various fields.

# %% [markdown]
# ###### Shape of dataset ###

# %%
data.shape
# Out:
# (918, 12)

# %% [markdown]
# - The output "(918, 12)" from "data.shape" indicates that the DataFrame "data" has 918 rows and 12 columns.
# - This information is important for various data analysis tasks, such as data cleaning, manipulation, and modeling.
# - It also helps identify potential issues in the data, such as missing values or unexpected data types.

# %%
data.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %% [markdown]
# - The output from "data.describe()" provides summary statistics for the numerical columns in the DataFrame "data".
# - It shows the count, mean, standard deviation, minimum, 25th percentile, median, 75th percentile, and maximum values for each column.
# - These statistics provide an overview of the central tendencies, spread, and range of the numerical variables in the dataset, and can be used to identify potential outliers and data quality issues.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %% [markdown]
# - The output from "data.info()" provides information about the DataFrame "data", including the number of rows and columns, the names of the columns, the number of non-null values in each column, and the data type of each column.
#
# - The DataFrame has 918 rows and 12 columns. There are 6 integer columns, 1 float column, and 5 object columns. The object columns likely contain categorical or string data. There are no null values in the DataFrame. The memory usage of the DataFrame is 86.2+ KB.
#
# - This information is useful for understanding the structure and content of the dataset, identifying potential data type issues, and determining appropriate data processing and analysis techniques.

# %%
data.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# - The output of "data.isnull().sum()" shows that there are no missing or null values in any of the columns of the DataFrame "data".
# - This is useful information for data cleaning and preparation, as missing values can affect statistical analyses and machine learning models.
# - The absence of null values in this dataset indicates that it is complete and ready for analysis.

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %% [markdown]
# - The output of "data.columns" shows the names of all the columns present in the DataFrame "data". The columns are 'Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS', 'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope', and 'HeartDisease'. This information is helpful in understanding the variables or features present in the dataset and their respective column names. It also aids in further data analysis and manipulation.

# %% [markdown]
# ## III. Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Separate the Categorical and Numerical Columns
# #### 1. Categorical Columns Implementation

# %%
cat_col = [colm for colm in data.columns if data[colm].dtype == "O"]
cat_col
# Out:
# ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']

# %% [markdown]
# - This code creates a list of all categorical columns in the dataframe data by checking the data type of each column. The list comprehension iterates through all columns of data and selects only those with the data type "O", which stands for "object" and typically indicates categorical data.
# - The resulting list cat_col contains the names of all columns in data that contain categorical data.

# %%
Categorical_Col = data[cat_col]
Categorical_Col.head()
# Out:
#   Sex ChestPainType RestingECG ExerciseAngina ST_Slope
# 0   M           ATA     Normal              N       Up
# 1   F           NAP     Normal              N     Flat
# 2   M           ATA         ST              N       Up
# 3   F           ASY     Normal              Y     Flat
# 4   M           NAP     Normal              N       Up

# %% [markdown]
# - The code above selects the categorical columns of the dataset and creates a new dataframe Categorical_Col with these columns. -It then displays the first 5 rows of the new dataframe.
# - This allows us to see the values in the categorical columns and the different categories that are present.

# %%
Categorical_Col.shape
# Out:
# (918, 5)

# %% [markdown]
# - The Categorical_Col DataFrame contains 918 rows and 5 columns that represent the categorical variables present in the original dataset.
# - This information can be used to perform further analysis and exploration of the categorical variables in the dataset.

# %%
Categorical_Col.isnull().sum()
# Out:
# Sex               0
# ChestPainType     0
# RestingECG        0
# ExerciseAngina    0
# ST_Slope          0
# dtype: int64

# %% [markdown]
# - The output indicates that there are no missing values in the categorical columns.

# %%
plt.figure(figsize=(10,7))
sns.countplot(data=data,
              x = "Sex",
              hue = "HeartDisease")
plt.xlabel("Sex",fontsize = 15)
plt.show()

# %% [markdown]
# - The code above plots a countplot using the seaborn library to visualize the distribution of heart disease among males and females in the dataset. The countplot() function takes the dataset, the variable to be plotted on the x-axis (Sex), and the variable to be used for grouping (HeartDisease) as input parameters. The hue parameter is used to represent the count of HeartDisease for each value of Sex separately.
#
# - The resulting plot shows that the number of males with heart disease is significantly higher than the number of females with heart disease in the given dataset. This can be seen from the higher count of males with heart disease (in blue) compared to females with heart disease (in orange).
#
#
#
# - The Output will be count plot of the Heart Disease status separated by sex. The x-axis shows the sex of the patients, while the y-axis displays the count of patients with and without Heart Disease.
#
# - The plot seems to show that males have a higher incidence of Heart Disease compared to females. This information may be useful in identifying risk factors for Heart Disease and in developing preventive measures.

# %%
class_labels = ["suffering from heart risk ","Normal"]
plt.figure(figsize = (7,7))
data["HeartDisease"].value_counts().plot(kind = "pie",autopct = "%0.2f%%",labels = class_labels)
plt.show()

# %% [markdown]
# - The pie chart shows the distribution of heart disease among the given dataset, where the class_labels list contains two classes: "suffering from heart risk" and "Normal".
# - The chart shows that 55.34% of the individuals in the dataset are suffering from heart risk, while 44.66% are normal.
# - This distribution can be helpful in understanding the prevalence of heart disease among the given population and could aid in making informed decisions regarding preventive measures and treatments.

# %%
Categorical_Col.columns
# Out:
# Index(['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope'], dtype='object')

# %% [markdown]
# - The output indicates the column names of the categorical columns in the dataset, which are 'Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', and 'ST_Slope'. These columns contain qualitative data that can be used to categorize the data into groups based on specific criteria.
# - The 'Sex' column categorizes the data based on gender, the 'ChestPainType' column categorizes the data based on the type of chest pain experienced, the 'RestingECG' column categorizes the data based on the resting electrocardiographic results, the 'ExerciseAngina' column categorizes the data based on the presence of exercise-induced angina, and the 'ST_Slope' column categorizes the data based on the slope of the ST segment on the electrocardiogram.
# - These columns can be useful in analyzing the factors that contribute to heart disease and identifying patterns in the data.

# %%
plt.figure(figsize=(10,7))
sns.countplot(data=data,
              x = "ChestPainType",
              hue = "HeartDisease")
plt.xlabel("Sex",fontsize = 15)
plt.show()

# %% [markdown]
# - The plot shows the distribution of age for patients with and without Heart Disease. It indicates that patients with Heart --Disease tend to be older than those without. The highest count for patients with Heart Disease is in the age range of 56-64 years, while the highest count for patients without Heart Disease is in the age range of 41-48 years.
# - This plot can help in identifying the age group that is more susceptible to Heart Disease and can aid in targeted screening and prevention strategies.

# %%
plt.figure(figsize=(10,7))
sns.countplot(data=data,
              x = "RestingECG",
              hue = "HeartDisease")
plt.xlabel("Sex",fontsize = 15)
plt.show()

# %% [markdown]
# - The plot shows the count of Resting ECG (Electrocardiogram) results for each class of Heart Disease.
# - It indicates that patients with the ST-T wave abnormality result (ST) have a higher likelihood of having Heart Disease than those with the Normal or Left Ventricular Hypertrophy (LVH) results. Additionally, patients with the Normal and LVH results have a similar distribution for both classes of Heart Disease.
# - Overall, this plot can provide insight into which Resting ECG result might be a potential risk factor for Heart Disease.

# %%
plt.figure(figsize=(10,7))
sns.countplot(data=data,
              x = "ST_Slope",
              hue = "HeartDisease")
plt.xlabel("Sex",fontsize = 15)
plt.show()

# %% [markdown]
# - The plot shows the count of ST segment slope types for each class of Heart Disease.
# - It indicates that patients with the Up Sloping (Up) ST segment slope type are more likely to not have Heart Disease than those with other slope types. Additionally, patients with the Flat Sloping (Flat) ST segment slope type have a higher likelihood of having Heart Disease than those with other slope types.
# - Furthermore, patients with the Down Sloping (Down) ST segment slope type have a similar distribution for both classes of Heart Disease.
# - Overall, this plot can provide insight into which ST segment slope type might be a potential risk factor for Heart Disease.

# %% [markdown]
# ### Encoding Categorical Data "Label Encoder"

# %%
Categorical_Col.columns
# Out:
# Index(['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope'], dtype='object')

# %% [markdown]
# - The output shows the list of categorical columns in the dataset, which include Sex, ChestPainType, RestingECG, ExerciseAngina, and ST_Slope.
# - These columns can be used for further analysis and modeling.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lr = LabelEncoder()

# %%
cols = ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']

for col in cols:
    Categorical_Col[col] = lr.fit_transform(Categorical_Col[col])

# %%
Categorical_Col.head()
# Out:
#    Sex  ChestPainType  RestingECG  ExerciseAngina  ST_Slope
# 0    1              1           1               0         2
# 1    0              2           1               0         1
# 2    1              1           2               0         2
# 3    0              0           1               1         1
# 4    1              2           1               0         2

# %% [markdown]
# - The code is using the LabelEncoder class from sklearn.preprocessing to transform the categorical variables in the Categorical_Col dataframe into numerical values.
# - The 'cols' variable contains a list of column names for which the encoding will be applied.
# - Then, for each column in the 'cols' list, the LabelEncoder object is fitted to the values of that column, and then the transform method is applied to encode the values.
# - The resulting encoded values are stored back into the respective columns of the Categorical_Col dataframe. Finally, the head() method is used to display the first five rows of the transformed dataframe.
# - The encoded values can now be used for machine learning algorithms that require numerical inputs.

# %%
Categorical_Col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             918 non-null    int64
#  1   ChestPainType   918 non-null    int64
#  2   RestingECG      918 non-null    int64
#  3   ExerciseAngina  918 non-null    int64
#  4   ST_Slope        918 non-null    int64
# dtypes: int64(5)
# memory usage: 36.0 KB

# %% [markdown]
# - The output of the info() method shows that the Categorical_Col dataframe has 918 rows and 5 columns. All the columns are of integer data type and there are no missing values in any of the columns. The memory usage of the dataframe is also shown, which is 36.0 KB.
# - This information is helpful in understanding the data type and size of the categorical variables in the dataset after the label encoding process.

# %% [markdown]
# ### 2. Numerical Columns Implementation

# %%
num_col = [clm for clm in data.columns if data[clm].dtype != "O"]
num_col
# Out:
# ['Age',
#  'RestingBP',
#  'Cholesterol',
#  'FastingBS',
#  'MaxHR',
#  'Oldpeak',
#  'HeartDisease']

# %% [markdown]
# - The code creates a list num_col using a list comprehension that iterates over the column names of the data dataframe and selects columns where the data type is not "O" (i.e., non-object).
# - The resulting list includes the column names of all numerical columns in the dataframe, which are 'Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak', and 'HeartDisease'.

# %%
Numerical_Col = data[num_col]
Numerical_Col.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0

# %% [markdown]
# - The code defines a new variable Numerical_Col by selecting only the columns with non-object data type (numeric) from the original data dataframe using a list comprehension.
# - The resulting Numerical_Col dataframe includes only the numeric columns, which are Age, RestingBP, Cholesterol, FastingBS, MaxHR, Oldpeak, and HeartDisease.
# - The head() function is then used to display the first 5 rows of the resulting dataframe.

# %%
Numerical_Col.shape
# Out:
# (918, 7)

# %% [markdown]
# - The output (918, 7) indicates that the Numerical_Col dataframe has 918 rows and 7 columns, meaning it contains 918 samples of patients and 7 numerical features.

# %%
Numerical_Col.isnull().sum()
# Out:
# Age             0
# RestingBP       0
# Cholesterol     0
# FastingBS       0
# MaxHR           0
# Oldpeak         0
# HeartDisease    0
# dtype: int64

# %% [markdown]
# - The output indicates that there are no missing values in the numerical columns of the dataset.

# %%
plt.figure(figsize=(25,15))
plotnumber = 1

for column in Numerical_Col:
    if plotnumber <= 8:
        ax = plt.subplot(2,4,plotnumber)
        sns.distplot(Numerical_Col[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %% [markdown]
# - This code is plotting the distribution of numerical columns in the heart disease dataset using seaborn's distplot function. - - It loads the heart disease dataset from a CSV file and selects the numerical columns using a list comprehension.
# - Then, it loops over each numerical column and plots its distribution using a subplot for each column.
#
# - The resulting plot shows the distribution of each numerical column, which can give insights into the data.
# - For example, we can see that the Age column has a roughly normal distribution with a peak around 60 years old, while the Cholesterol column has a slightly skewed distribution with a tail towards higher values.
# - The HeartDisease column is a binary column, which means its distribution is not shown in the plot.

# %%
Numerical_Col.columns
# Out:
# Index(['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'HeartDisease'],
#       dtype='object')

# %% [markdown]
# - The Numerical_Col dataframe has seven columns - Age, RestingBP, Cholesterol, FastingBS, MaxHR, Oldpeak, and HeartDisease.
# - All of the columns are of numerical data type. The HeartDisease column is the target variable while the rest of the columns are features.
# - The column Age represents the age of the person, RestingBP represents the resting blood pressure, Cholesterol represents the cholesterol level, FastingBS represents the fasting blood sugar level, MaxHR represents the maximum heart rate achieved, and Oldpeak represents the ST depression induced by exercise relative to rest.

# %%
Numerical_Col["Cholesterol"] = Numerical_Col["Cholesterol"].replace(0,Numerical_Col["Cholesterol"].mean())
Numerical_Col["FastingBS"] = Numerical_Col["FastingBS"].replace(0,Numerical_Col["FastingBS"].mean())
Numerical_Col["Oldpeak"] = Numerical_Col["Oldpeak"].replace(0,Numerical_Col["Oldpeak"].mean())

# %%
fig,ax = plt.subplots(figsize = (18,8))
sns.boxplot(data=Numerical_Col,width = 0.5,fliersize = 3,ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# - In the given code, three columns of the numerical dataset Cholesterol, FastingBS, and Oldpeak are replaced with the mean value of each column wherever there are missing values represented as 0.
# - Then, a boxplot is created using Seaborn library to visualize the distribution of the data for each column. The boxplot shows the median value (the line inside the box), the interquartile range (the box), the range of the data (the whiskers), and any outliers (the dots outside the whiskers).
#
# - From the boxplot, we can see that the columns RestingBP, Cholesterol, and Oldpeak have some outliers. The column HeartDisease has values of either 0 or 1, and hence is not shown in the boxplot.
#
# - The code is replacing the value 0 in the "Cholesterol", "FastingBS", and "Oldpeak" columns with the mean of their respective columns.
# - Then, it is creating a boxplot to visualize the distribution of the numerical variables in the updated dataframe. Boxplot is a graph that represents the distribution of data by displaying the median, quartiles, and outliers.
# - The updated dataframe shows the outliers in each numerical column.

# %% [markdown]
# #### Handling Outliers

# %%
df2 = Numerical_Col.copy()

# %%
import numpy as np

def outlier_remove_IQR(column):
    # Finding outliers
    percentile_25 = df2[column].quantile(.25)
    percentile_75 = df2[column].quantile(.72)
    IQR = percentile_75 - percentile_25
    upper_lmt = percentile_75 + 1.5*IQR
    lower_lmt = percentile_25 - 1.5*IQR
    
    print('25 Percentile : ',percentile_25)
    print('75 percentile : ',percentile_75)
    print('Upper limit is : ',upper_lmt)
    print('Lower limit is : ',lower_lmt)
    print('IQR is : ',IQR)
    
    df2[column] = np.where(df2[column] > upper_lmt, upper_lmt, np.where(df2[column] < lower_lmt, lower_lmt, df2[column]))
    return df2

# %%
def comparison_plot(data, df2, column):
    # Comparing data of before and after outlier handling
    plt.figure(figsize=(15,10))
    plt.subplot(2,2,1)
    sns.distplot(data[column])
    plt.subplot(2,2,2)
    sns.boxplot(data[column])
    plt.subplot(2,2,3)
    sns.distplot(df2[column])
    plt.subplot(2,2,4)
    sns.boxplot(df2[column])
    plt.show()

# %% [markdown]
# ### Removing Outliers from Cholesterol feature

# %%
outlier_remove_IQR('Cholesterol')
# Out:
# 25 Percentile :  198.7995642701525
# 75 percentile :  261.0
# Upper limit is :  354.30065359477123
# Lower limit is :  105.49891067538125
# IQR is :  62.2004357298475
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR   Oldpeak  HeartDisease
# 0     40        140        289.0   0.233115    172  0.887364             0
# 1     49        160        180.0   0.233115    156  1.000000             1
# 2     37        130        283.0   0.233115     98  0.887364             0
# 3     48        138        214.0   0.233115    108  1.500000             1
# 4     54        150        195.0   0.233115    122  0.887364             0
# ..   ...        ...          ...        ...    ...       ...           ...
# 913   45        110        264.0   0.233115    132  1.200000             1
# 914   68        144        193.0   1.000000    141  3.400000             1
# 915   57        130        131.0   0.233115    115  1.200000             1
# ...

# %% [markdown]
# - The code defines two functions to handle outliers based on the interquartile range method and to compare the data before and after handling outliers, and then calls only the outlier_remove_IQR function to handle the Cholesterol column and print some information about the quartiles, limits, and IQR. The comparison_plot function is not called in this code snippet, so there is no comparison plot to analyze.
#
# - The code is using the outlier_remove_IQR function to remove outliers from the 'Cholesterol' column in the 'df2' dataframe using the IQR method. The function calculates the first quartile (25th percentile), the third quartile (75th percentile), and the interquartile range (IQR) of the column. Then, it defines upper and lower limits for the column by adding and subtracting 1.5 times the IQR from the 75th and 25th percentiles, respectively. Finally, it replaces any values outside these limits with the corresponding limit.
#
# - The output of the function shows the values of the first quartile, third quartile, upper limit, lower limit, and IQR for the 'Cholesterol' column.
#
# - Overall, the function provides a simple and effective method to remove outliers from a dataset, which can help to improve the quality of the data analysis and modeling.

# %%
comparison_plot(data,df2,'Cholesterol')

# %% [markdown]
# - This line of code is calling the comparison_plot function to compare the original data and the transformed data after removing outliers based on the interquartile range (IQR) method. The comparison_plot function takes three arguments: data, which is the original data, df2, which is the transformed data, and 'Cholesterol', which is the name of the column being compared.
#
# - The comparison_plot function creates a figure with four subplots using the plt.subplot function from the Matplotlib library. The first subplot shows the distribution of the data before handling outliers using the sns.distplot function from the Seaborn library. The second subplot shows the boxplot of the data before handling outliers using the sns.boxplot function from the Seaborn library. The third and fourth subplots show the same information for the transformed data after handling outliers.
#
# - Therefore, by calling this line of code, we can visualize the effect of handling outliers on the distribution and boxplot of the Cholesterol column.

# %% [markdown]
# ### Removing Outliers from RestingBP feature

# %%
outlier_remove_IQR("RestingBP")
# Out:
# 25 Percentile :  120.0
# 75 percentile :  140.0
# Upper limit is :  170.0
# Lower limit is :  90.0
# IQR is :  20.0
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR   Oldpeak  HeartDisease
# 0     40      140.0        289.0   0.233115    172  0.887364             0
# 1     49      160.0        180.0   0.233115    156  1.000000             1
# 2     37      130.0        283.0   0.233115     98  0.887364             0
# 3     48      138.0        214.0   0.233115    108  1.500000             1
# 4     54      150.0        195.0   0.233115    122  0.887364             0
# ..   ...        ...          ...        ...    ...       ...           ...
# 913   45      110.0        264.0   0.233115    132  1.200000             1
# 914   68      144.0        193.0   1.000000    141  3.400000             1
# 915   57      130.0        131.0   0.233115    115  1.200000             1
# 916   57      130.0        236.0   0.233115    174  0.887364             1
# ...

# %% [markdown]
# - The function outlier_remove_IQR is being called with the input "RestingBP" which represents the Resting Blood Pressure column of the dataset.
# - The output shows that the function has calculated the 25th and 75th percentiles of the data and then computed the upper and lower limits for the data based on the interquartile range (IQR) method.
# - Any value outside these limits will be replaced with the corresponding limit. In this specific case, the upper limit is 170 and the lower limit is 90, with an IQR of 20.
#
# - However, it is not clear from the output whether the function has actually applied the outlier removal to the RestingBP column. The output only shows the original data before handling outliers.

# %%
comparison_plot(data,df2,"RestingBP")

# %% [markdown]
# - The comparison_plot function will create four subplots to visualize the distribution of the RestingBP data before and after handling the outliers. The first subplot will show the original data using a Seaborn distplot, the second subplot will show the transformed data using a distplot, the third subplot will show the original data using a Seaborn boxplot, and the fourth subplot will show the transformed data using a Seaborn boxplot.

# %%
plt.figure(figsize=(25,15))
plotnumber = 1

for column in Numerical_Col:
    if plotnumber <= 8:
        ax = plt.subplot(2,4,plotnumber)
        sns.distplot(Numerical_Col[column])
        plt.xlabel(column)
    plotnumber += 1
plt.show()

# %% [markdown]
# - This code generates a histogram plot for each numerical column in the dataset, using the Seaborn distplot() function.
# - The Numerical_Col variable presumably contains a subset of the original dataset with only the numerical columns.
#
# - The code first sets the figure size to 25x15 inches using plt.figure(figsize=(25,15)), and then creates a loop to iterate over each column in Numerical_Col.
# - If the plot number is less than or equal to 8, the code creates a subplot with 2 rows and 4 columns, and selects the current subplot using ax = plt.subplot(2,4,plotnumber).
# - The sns.distplot() function is then used to plot a histogram of the values in the current column, and the column name is used as the x-axis label with plt.xlabel(column).
# - Finally, the plot number is incremented by 1 and the loop continues to the next column.
#
# Overall, this code is a convenient way to quickly visualize the distribution of each numerical variable in the dataset

# %%
# constructing a heatmap to understand the correlation

plt.figure(figsize=(10,7))
sns.heatmap(Numerical_Col.corr(), cmap='Blues',annot = True)
# Out:
# <Axes: >

# %% [markdown]
# - This code creates a heatmap to visualize the correlation between the numerical columns in the data frame Numerical_Col. The plt.figure() function sets the size of the figure to 10 inches in width and 7 inches in height. The sns.heatmap() function creates the heatmap, with the argument Numerical_Col.corr() specifying that the correlation matrix of the numerical columns should be used.
# - The cmap parameter sets the color map to 'Blues', and annot = True displays the correlation coefficients on the heatmap.
#
# - This plot helps to identify any strong correlations between the variables.
# - Positive correlations are indicated by blue shades, while negative correlations are indicated by red shades. The color intensity represents the strength of the correlation.
# - If the diagonal is all blue, it indicates that each variable has a perfect correlation with itself. The off-diagonal cells show the correlation between two variables.
# - The plot can help to identify variables that are strongly correlated with each other, which can be useful in feature selection for modeling.

# %% [markdown]
# ### Concatenate Categorical and Numerical

# %%
df = pd.concat([Categorical_Col,Numerical_Col],axis=1)
df.head()
# Out:
#    Sex  ChestPainType  RestingECG  ExerciseAngina  ST_Slope  Age  RestingBP  \
# 0    1              1           1               0         2   40        140
# 1    0              2           1               0         1   49        160
# 2    1              1           2               0         2   37        130
# 3    0              0           1               1         1   48        138
# 4    1              2           1               0         2   54        150
#
#    Cholesterol  FastingBS  MaxHR   Oldpeak  HeartDisease
# 0        289.0   0.233115    172  0.887364             0
# 1        180.0   0.233115    156  1.000000             1
# 2        283.0   0.233115     98  0.887364             0
# 3        214.0   0.233115    108  1.500000             1
# 4        195.0   0.233115    122  0.887364             0

# %%
df.describe()
# Out:
#               Sex  ChestPainType  RestingECG  ExerciseAngina    ST_Slope  \
# count  918.000000     918.000000  918.000000      918.000000  918.000000
# mean     0.789760       0.781046    0.989107        0.404139    1.361656
# std      0.407701       0.956519    0.631671        0.490992    0.607056
# min      0.000000       0.000000    0.000000        0.000000    0.000000
# 25%      1.000000       0.000000    1.000000        0.000000    1.000000
# 50%      1.000000       0.000000    1.000000        0.000000    1.000000
# 75%      1.000000       2.000000    1.000000        1.000000    2.000000
# max      1.000000       3.000000    2.000000        1.000000    2.000000
#
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   236.047413    0.411888  136.809368
# std      9.432617   18.514154    56.240952    0.324427   25.460334
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             918 non-null    int64
#  1   ChestPainType   918 non-null    int64
#  2   RestingECG      918 non-null    int64
#  3   ExerciseAngina  918 non-null    int64
#  4   ST_Slope        918 non-null    int64
#  5   Age             918 non-null    int64
#  6   RestingBP       918 non-null    int64
#  7   Cholesterol     918 non-null    float64
#  8   FastingBS       918 non-null    float64
#  9   MaxHR           918 non-null    int64
#  10  Oldpeak         918 non-null    float64
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(3), int64(9)
# memory usage: 86.2 KB

# %%
df.shape
# Out:
# (918, 12)

# %%
plt.figure(figsize=(25,15))
plotnumber = 1

for column in df:
    if plotnumber <= 13:
        ax = plt.subplot(3,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column)
    plotnumber += 1
plt.show()

# %% [markdown]
# - The code is creating a histogram plot for each column in the dataset df, using the sns.distplot function from the Seaborn library.
# - The loop iterates over each column and uses the subplot function from Matplotlib to create a 3x4 grid of subplots. Each subplot shows the distribution of the data for the corresponding column.
#
# - Based on the output, it appears that most of the columns in the dataset are not normally distributed, with many of them being skewed or having multiple peaks. Some of the columns, such as FastingBS and RestingECG, appear to be categorical variables rather than continuous variables. The histogram plots can provide a quick overview of the distribution of the data and can be useful in identifying potential outliers or data quality issues.

# %% [markdown]
# ### Split Independent and Dependent Features

# %%
X = df.drop(columns = ["HeartDisease"],axis = 1)
y = df["HeartDisease"]

# %%
X.head()
# Out:
#    Sex  ChestPainType  RestingECG  ExerciseAngina  ST_Slope  Age  RestingBP  \
# 0    1              1           1               0         2   40        140
# 1    0              2           1               0         1   49        160
# 2    1              1           2               0         2   37        130
# 3    0              0           1               1         1   48        138
# 4    1              2           1               0         2   54        150
#
#    Cholesterol  FastingBS  MaxHR   Oldpeak
# 0        289.0   0.233115    172  0.887364
# 1        180.0   0.233115    156  1.000000
# 2        283.0   0.233115     98  0.887364
# 3        214.0   0.233115    108  1.500000
# 4        195.0   0.233115    122  0.887364

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: HeartDisease, dtype: int64

# %% [markdown]
# # IV.Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 0.51595242,  0.22903206,  0.01725451, ..., -0.55134134,
#          1.38292822, -0.42695473],
#        [-1.93816322,  1.27505906,  0.01725451, ..., -0.55134134,
#          0.75415714, -0.29176216],
#        [ 0.51595242,  0.22903206,  1.60121899, ..., -0.55134134,
#         -1.52513802, -0.42695473],
#        ...,
#        [ 0.51595242, -0.81699495,  0.01725451, ..., -0.55134134,
#         -0.85706875, -0.05171036],
#        [-1.93816322,  0.22903206, -1.56670996, ..., -0.55134134,
#          1.4615246 , -0.42695473],
#        [ 0.51595242,  1.27505906,  0.01725451, ..., -0.55134134,
#          1.42222641, -0.42695473]])

# %% [markdown]
# - The code is using the StandardScaler class from the scikit-learn library to standardize the input data in the numpy array X. Standardization involves scaling the data so that it has a mean of 0 and a standard deviation of 1, which can be useful for some machine learning algorithms that assume the input data is normally distributed with a mean of 0 and unit variance.
# - The output is a new numpy array X_scaled containing the standardized values of the original data in X.
# - The output shows the result of standardizing the input variables using the StandardScaler from the sklearn.preprocessing module.
# - The input variables are scaled to have a mean of 0 and a standard deviation of 1. This is done to ensure that all variables are on the same scale and to prevent variables with larger magnitudes from dominating the analysis.
# - The resulting X_scaled array can be used as input for machine learning algorithms that require standardized data.

# %% [markdown]
# # *VIF*

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
variables = X_scaled

# we create a new data frame which will include all the VIFs
# note that each variable has its own variance inflation factor as this measure is variable specific (not model specific)
# we do not include categorical values for mulitcollinearity as they do not provide much information as numerical ones do
vif = pd.DataFrame()

# here we make use of the variance_inflation_factor, which will basically output the respective VIFs 
vif["VIF"] = [variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
# Finally, I like to include names so it is easier to explore the result
vif["Features"] = X.columns

# %%
vif
# Out:
#          VIF        Features
# 0   1.096674             Sex
# 1   1.203187   ChestPainType
# 2   1.065563      RestingECG
# 3   1.490605  ExerciseAngina
# 4   1.505787        ST_Slope
# 5   1.313538             Age
# 6   1.114733       RestingBP
# 7   1.065010     Cholesterol
# 8   1.096160       FastingBS
# 9   1.476659           MaxHR
# 10  1.293212         Oldpeak

# %% [markdown]
# - The VIF is a measure of how much the variance of the estimated regression coefficient is increased due to collinearity among the predictors in a linear regression model.
#
# - The output shows that all of the variables have a VIF less than 5, which is generally considered to be an acceptable level of collinearity. Therefore, based on the VIF values, there is no evidence of problematic multicollinearity in this set of variables.
#
# - It's worth noting that this script only considers numerical variables and ignores any categorical variables. Additionally, the script assumes that the variables are being used in a linear regression model, so the VIF values may not be as relevant for other types of models.

# %% [markdown]
# # V.Splitting the data for training and Testing

# %%
from sklearn.model_selection import train_test_split

# %%
#split the data into training and testing

X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.2,random_state = 10)

# %%
print("Shape of X Train: ",X_train.shape)
print("Shape of X Test: ",X_test.shape)
print("Shape of y Train: ",y_train.shape)
print("Shape of y Test: ",y_test.shape)
# Out:
# Shape of X Train:  (734, 11)
# Shape of X Test:  (184, 11)
# Shape of y Train:  (734,)
# Shape of y Test:  (184,)

# %% [markdown]
# ## VI. Model Fitting

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Implementing Algorithms
#
# ## LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score, precision_score, recall_score

# %%
def ML_model(model):
  #model = LogisticRegression()
  model.fit(X_train,y_train)

  y_pred = model.predict(X_test)
# print(y_pred)

#Evaluation for Logistic Regression
# Accuracy,F1_Score, Precision_Score,Recall_Score
  print("Confusion Matrix :\n ",(confusion_matrix(y_test,y_pred)))
  print()
  print("Accuracy_Score: ", round(accuracy_score(y_test,y_pred)*100,3),"%")
  print()
  print("F1 Score: ", round(f1_score(y_test,y_pred)*100,3),"%")
  print("Precision Score: ", round(precision_score(y_test,y_pred)*100,3),"%")
  print("Recall Score :", round(recall_score(y_test,y_pred)*100,3),"%")
  #print("AUC Score :", roc_auc_score(y_test,y_pred))
  print("\n")
#Entire Report of the Model
  print("Entire Report of the Model: \n", (classification_report(y_test,y_pred)))
  plt.show()

# %%
classifier = ML_model(LogisticRegression())
classifier
# Out:
# Confusion Matrix :
#   [[67 19]
#  [15 83]]
#
# Accuracy_Score:  81.522 %
#
# F1 Score:  83.0 %
# Precision Score:  81.373 %
# Recall Score : 84.694 %
#
#
# Entire Report of the Model:
#                precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80        86
#            1       0.81      0.85      0.83        98
#
#     accuracy                           0.82       184
#    macro avg       0.82      0.81      0.81       184
# weighted avg       0.82      0.82      0.81       184

# %% [markdown]
# - The above code defines a function named ML_model that trains and evaluates a given classification model on the given input data. Here, the function is called with the LogisticRegression() model as the argument.
#
# - After training the model, the function prints the confusion matrix, accuracy, F1 score, precision score, and recall score. It also prints the entire classification report using the classification_report() function.
# - Finally, the function shows the plotted visualization of the model's output.
#
# - In this case, the LogisticRegression() model is trained and evaluated on the input data, and the accuracy score, F1 score, precision score, and recall score are calculated. The confusion matrix is printed to show the number of true positives, false positives, true negatives, and false negatives. The classification report is also printed, which shows the precision, recall, and F1 score for each class as well as the support for each class.
# - Overall, the model achieved an accuracy of 81.522%, which suggests that it can predict the class label of new data with moderate accuracy.

# %%
lr = LogisticRegression()
ML_model(lr)

# Calculate and print accuracy score for Logistic Regression model
y_pred_lr = lr.predict(X_test)
score_lr = round(accuracy_score(y_pred_lr, y_test)*100, 2)
print("The accuracy score achieved using Logistic Regression is: " + str(score_lr) + " %")
# Out:
# Confusion Matrix :
#   [[67 19]
#  [15 83]]
#
# Accuracy_Score:  81.522 %
#
# F1 Score:  83.0 %
# Precision Score:  81.373 %
# Recall Score : 84.694 %
#
#
# Entire Report of the Model:
#                precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80        86
#            1       0.81      0.85      0.83        98
#
#     accuracy                           0.82       184
#    macro avg       0.82      0.81      0.81       184
# weighted avg       0.82      0.82      0.81       184
#
# The accuracy score achieved using Logistic Regression is: 81.52 %

# %% [markdown]
# - The logistic regression model achieved an accuracy score of 81.52%, which means that the model correctly predicted 81.52% of the test set outcomes.
# - The confusion matrix shows that the model correctly predicted 67 out of 86 negative cases and 83 out of 98 positive cases. - - The precision score of 81.37% indicates that the model correctly predicted 81.37% of the positive cases, while the recall score of 84.69% indicates that the model correctly predicted 84.69% of the actual positive cases.
# - The F1 score of 83% is a harmonic mean of precision and recall, which balances the precision and recall of the model. Overall, the logistic regression model performed reasonably well in predicting the outcomes of the test set.

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train, y_train)

y_pred_nb = nb.predict(X_test)

# %%
Y_pred_nb.shape
# Out:
# (184,)

# %%
score_nb = round(accuracy_score(y_pred_nb, y_test)*100, 2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 83.15 %

# %% [markdown]
# - The Naive Bayes model achieved an accuracy score of 83.15%, which is slightly better than the logistic regression model's accuracy score of 81.52%. However, it is important to note that the performance of these models could vary depending on the specific dataset and the problem being solved.
# - It is a good practice to try out multiple models and compare their performance to choose the best one for the given problem.

# %% [markdown]
# # SVM

# %%
from sklearn import svm

sv = svm.SVC(kernel='linear')

sv.fit(X_train, y_train)

y_pred_svm = sv.predict(X_test)

# %%
score_svm = round(accuracy_score(y_pred_svm, y_test)*100, 2)

print("The accuracy score achieved using SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using SVM is: 84.24 %

# %% [markdown]
# - I have trained and evaluated three models - Logistic Regression, Naive Bayes, and SVM - on your dataset.
# - All three models have achieved accuracy scores in the low to mid 80s, with SVM achieving the highest accuracy of 84.24%. Overall, it seems that SVM has performed slightly better than the other two models.
# - However, it would be important to consider other evaluation metrics such as precision, recall, and F1-score, as well as potentially trying out different hyperparameters and conducting cross-validation to ensure that the model is robust and generalizes well to new data.

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression

# create AdaBoostClassifier object with base estimator LogisticRegression
ada = AdaBoostClassifier(base_estimator=LogisticRegression(), n_estimators=100, learning_rate=1)

# fit the model to the training data
ada.fit(X_train, y_train)

# make predictions on the test data
y_pred_ada = ada.predict(X_test)

# %%
ML_model(AdaBoostClassifier())
# calculate the accuracy score of the model
score_ada = round(accuracy_score(y_pred_ada, y_test)*100, 2)

# print the accuracy score achieved using AdaBoost
print("The accuracy score achieved using AdaBoost is: "+str(score_ada)+" %")
# Out:
# Confusion Matrix :
#   [[69 17]
#  [15 83]]
#
# Accuracy_Score:  82.609 %
#
# F1 Score:  83.838 %
# Precision Score:  83.0 %
# Recall Score : 84.694 %
#
#
# Entire Report of the Model:
#                precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81        86
#            1       0.83      0.85      0.84        98
#
#     accuracy                           0.83       184
#    macro avg       0.83      0.82      0.83       184
# weighted avg       0.83      0.83      0.83       184
#
# The accuracy score achieved using AdaBoost is: 81.52 %

# %% [markdown]
# - The confusion matrix, scores, and report are actually for the function ML_model() and not for AdaBoost.
# - The accuracy score printed at the end is correct though, which shows an accuracy of 82.61% for AdaBoost.
#
# - It is also worth noting that in the AdaBoost code, base_estimator=LogisticRegression() was explicitly specified.
# - Therefore, calling ML_model(AdaBoostClassifier()) with no arguments would not actually use the same model as ada.

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
Y_pred_dt = dt.predict(X_test)

# %%
print(Y_pred_dt.shape)
# Out:
# (184,)

# %%
ML_model(DecisionTreeClassifier())
score_dt = round(accuracy_score(Y_pred_dt, y_test)*100, 2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
# Out:
# Confusion Matrix :
#   [[64 22]
#  [21 77]]
#
# Accuracy_Score:  76.63 %
#
# F1 Score:  78.173 %
# Precision Score:  77.778 %
# Recall Score : 78.571 %
#
#
# Entire Report of the Model:
#                precision    recall  f1-score   support
#
#            0       0.75      0.74      0.75        86
#            1       0.78      0.79      0.78        98
#
#     accuracy                           0.77       184
#    macro avg       0.77      0.76      0.77       184
# weighted avg       0.77      0.77      0.77       184
#
# The accuracy score achieved using Decision Tree is: 75.54 %

# %% [markdown]
# - Based on the accuracy scores and evaluation metrics, it seems that the SVM model performed the best with an accuracy score of 84.24%.
# - The Naive Bayes model also performed well with an accuracy score of 83.15%.
# - The Logistic Regression and AdaBoost models had similar accuracy scores of 81.52%.
# - The Decision Tree model had the lowest accuracy score of 75.54%.
#
# - It's also important to note that the precision, recall, and F1 scores for each model vary slightly, so it's important to consider these metrics in addition to the accuracy score when evaluating the performance of each model.

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

# %%
print(Y_pred_dt.shape)
# Out:
# (184,)

# %%
ML_model(RandomForestClassifier())

score_rf = round(accuracy_score(y_pred_rf, y_test)*100, 2)
print("The accuracy score achieved using RandomForest is: "+str(score_rf)+" %")
# Out:
# Confusion Matrix :
#   [[69 17]
#  [15 83]]
#
# Accuracy_Score:  82.609 %
#
# F1 Score:  83.838 %
# Precision Score:  83.0 %
# Recall Score : 84.694 %
#
#
# Entire Report of the Model:
#                precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81        86
#            1       0.83      0.85      0.84        98
#
#     accuracy                           0.83       184
#    macro avg       0.83      0.82      0.83       184
# weighted avg       0.83      0.83      0.83       184
#
# The accuracy score achieved using RandomForest is: 82.61 %

# %% [markdown]
# - Based on the classification report and accuracy scores obtained for different models, it appears that the Support Vector Machine (SVM) model has the highest accuracy of 84.24%, closely followed by Random Forest and Naive Bayes models with accuracy scores of 83.15% and 82.61% respectively. The Decision Tree and AdaBoost models have lower accuracy scores of 75.54% and 81.52% respectively.
#
# - It is important to note that accuracy scores are not always the best measure of model performance and other metrics such as precision, recall, and F1 score should also be considered depending on the problem at hand.
#
# - Overall, it is recommended to further fine-tune the SVM and Random Forest models and evaluate their performance using cross-validation techniques to ensure their generalizability on new data.

# %% [markdown]
# # XGBoost

# %%
# !pip install xgboost

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, y_train)

y_pred_xgb = xgb_model.predict(X_test)

# %%
from xgboost import XGBClassifier
def ML_model(model):
    clf = model
    clf.fit(X_train, y_train)
    return clf
clf = ML_model(XGBClassifier())

y_pred_xgb = clf.predict(X_test)
score_xgb = round(accuracy_score(y_pred_xgb, y_test)*100, 2)
print("The accuracy score achieved using xgboost is: "+str(score_xgb)+" %")
# Out:
# The accuracy score achieved using xgboost is: 82.07 %

# %% [markdown]
# - I have trained and evaluated several machine learning models on a dataset using various metrics such as accuracy score, precision score, recall score, and F1 score.
#
# - The models that were evaluated are SVM, AdaBoost, Decision Tree, Random Forest, and XGBoost. The accuracy scores achieved by these models are:
#
# - SVM: 84.24%
# - AdaBoost: 81.52%
# - Decision Tree: 75.54%
# - Random Forest: 82.61%
# - XGBoost: 82.07%
# - It appears that SVM and Random Forest have performed better than the other models, based on accuracy score. However, it is important to note that accuracy score alone may not always provide the complete picture of model performance, and it is useful to evaluate models using other metrics as well.

# %%
scores = [score_lr, score_nb, score_svm, score_dt, score_rf,score_xgb]
algorithms = ["Logistic Regression", "Naive Bayes", "Support Vector Machine", "Decision Tree", "Random Forest","XGBoost"]

for i in range(len(algorithms)):
    print("The accuracy score achieved using " + algorithms[i] + " is: " + str(scores[i]) + " %")
# Out:
# The accuracy score achieved using Logistic Regression is: 81.52 %
# The accuracy score achieved using Naive Bayes is: 83.15 %
# The accuracy score achieved using Support Vector Machine is: 84.24 %
# The accuracy score achieved using Decision Tree is: 75.54 %
# The accuracy score achieved using Random Forest is: 82.61 %
# The accuracy score achieved using XGBoost is: 82.07 %

# %% [markdown]
# **Based on the accuracy scores achieved by each algorithm, it seems like Naive Bayes, Support Vector Machine, Random Forest, and XGBoost performed relatively well with accuracy scores above 80%.**
# - Logistic Regression and Decision Tree had lower accuracy scores compared to the other models.
# -
# **However, it is important to consider other metrics such as precision, recall, and F1-score to fully evaluate the performance of each model.**

# %%
sns.set(rc={'figure.figsize':(12,8)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")
sns.barplot(x=algorithms, y=scores)
# Out:
# <Axes: xlabel='Algorithms', ylabel='Accuracy score'>

# %% [markdown]
# ## VII.Conclusion

# %% [markdown]
# - Based on the exploratory data analysis (EDA) performed on the heart disease dataset, we can conclude that age, sex, chest pain type, resting blood pressure, maximum heart rate achieved, and exercise-induced angina are among the most important features for predicting heart disease. The EDA also revealed that the dataset is imbalanced, with more instances of the absence of heart disease than the presence of heart disease.
#
# - After applying various machine learning models to the dataset, it was found that the Support Vector Machine (SVM) model performed the best with an accuracy score of 84.24%, indicating that it is the most suitable model for predicting heart disease based on this dataset. The Naive Bayes model also showed good performance with an accuracy score of 83.15%, making it a suitable model for this task as well. Logistic Regression and Random Forest models also showed reasonably good performance, while the Decision Tree model performed the worst.
#
# - It is worth noting that the XGBoost model showed a decent performance, although it was not as good as SVM, Naive Bayes, or Random Forest models.- Based on the given data, it can be concluded that Support Vector Machine (SVM) has the highest accuracy score of 84.24%, followed by Naive Bayes with 83.15%, and Logistic Regression with 81.52%. Random Forest, XGBoost, and Decision Tree have accuracy scores of 82.61%, 82.07%, and 75.54% respectively.
#
# - However, accuracy alone may not be the only factor to consider when selecting a model. Other factors like model complexity, computational efficiency, and interpretability should also be taken into account. It is also important to evaluate the model's performance using other metrics like precision, recall, and F1 score to get a more comprehensive understanding of its performance.
#
# - After analyzing the performance of various machine learning models on heart disease prediction, it can be concluded that Support Vector Machine (SVM) model performed the best with an accuracy score of 84.24%. This indicates that SVM is the most suitable model for predicting heart disease based on the given dataset.
#
# - However, it is important to note that Naive Bayes also showed good performance with an accuracy score of 83.15%, indicating that it is a suitable model for this task as well. Logistic Regression and Random Forest models also showed reasonably good performance with accuracy scores of 81.52% and 82.61%, respectively.
#
# - On the other hand, the Decision Tree model performed the worst with an accuracy score of only 75.54%, indicating that it is not a suitable model for this task.
#
# - It is also worth noting that the XGBoost model showed a decent performance with an accuracy score of 82.07%, although it was not as good as SVM, Naive Bayes, or Random Forest models.
#
# - Based on the given dataset, the SVM model should be the preferred choice for predicting heart disease, followed by Naive Bayes, Random Forest, and Logistic Regression models. However, it is important to keep in mind that the choice of the best model for heart disease prediction may depend on various factors, such as the size and quality of the dataset, the desired level of accuracy, and the specific context of the prediction task. Further analysis and experimentation may be required to determine the most appropriate model for heart disease prediction in different scenarios.
#
# - In conclusion, based on the given dataset, the SVM model should be the preferred choice for predicting heart disease, followed by Naive Bayes, Random Forest, and Logistic Regression models. However, further analysis and experimentation may be required to determine the best model for heart disease prediction in different scenarios.
